# %% [markdown]
# # Classification Analysis on Iris Dataset

# %% [markdown]
# ### Here the steps we are following is:
#
# - Take the Data
#
# - Filter the Data
#
# - Divide the input and Output
#
# - Train and test the variable
#
# - Run a classifier/ Regressor.
#
# - Fit the model
#
# - Predict the output.

# %% [markdown]
# ### Importing the Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sympy import Matrix


# LIBRARIES TO IGNORE WARNINGS
import warnings as w
w.filterwarnings('ignore')

# %% [markdown]
# ### Importing the dataset

# %%
iris=pd.read_csv("Iris.csv")

# %%
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#looking at the first 5 values of the dataset
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ### Displaying the samples

# %%
iris["Species"].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# ### Structure of the dataset

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# ### Checking the missing values

# %%
iris.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
iris.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# ### Shape of the Data

# %%
iris.shape
# Out:
# (150, 6)

# %% [markdown]
# ## Data Visualization

# %%
tmp = iris.drop('Id', axis=1)
g = sns.pairplot(tmp, hue='Species', markers='+')
plt.show()

# %%
iris.plot.scatter(x='SepalLengthCm', y='SepalWidthCm');

# %%
sns.scatterplot(data=iris, x="SepalLengthCm", y="SepalWidthCm", hue="Species");

# %%
sns.set_style("whitegrid")
sns.pairplot(data=iris, hue='Species',diag_kind='hist');

# %%
sns.violinplot(x='Species', y='PetalLengthCm', data=iris, size=6);

# %%
sns.boxplot(x='Species', y='SepalWidthCm', data=iris);

# %%
sns.boxplot(x='Species', y='SepalLengthCm', data=iris);

# %%
sns.boxplot(x='Species', y='PetalWidthCm', data=iris);

# %%
sns.boxplot(x='Species', y='SepalWidthCm', data=iris);

# %% [markdown]
# **Here we can that conclude that Iris Virginica has the highest sepal_length and petal_width.**

# %% [markdown]
# ## Steps for applying an algorithm

# %% [markdown]
# #### Spliting the dataset in independent and dependent variables

# %%
x=iris.iloc[:,:4].values
y=iris["Species"].values

# %% [markdown]
# #### Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=0)

# %% [markdown]
# #### Feature Scaling

# %%
print("*"*120)
print("STANDARDIZING THE DATASET".center(50))
print("*"*120)

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
# Out:
# ************************************************************************************************************************
#             STANDARDIZING THE DATASET
# ************************************************************************************************************************

# %% [markdown]
# #### TRAIN THE MODEL USING SVC WITH LINEAR KERNEL

# %% [markdown]
# **Here we are using SVC classifier to predict the accuracy of the model**

# %%
from sklearn.svm import SVC

# %%
svc = SVC(kernel="linear", random_state=0)

# %%
# Train the algorithm by using training input and training output
svc.fit(x_train, y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %%
x_train
# Out:
# array([[ 1.34636602,  0.61303014,  0.10850105,  0.94751783],
#        [ 0.16184701, -0.56776627, -0.12400121,  0.38491447],
#        [-1.11206965, -0.80392556,  1.03851009, -1.30289562],
#        [ 1.12287187,  0.25879121, -0.12400121,  0.60995581],
#        [ 1.23461894,  0.61303014, -0.58900572,  1.00377816],
#        [-0.39688836, -0.80392556, -0.82150798,  0.04735245],
#        [-1.31321439, -0.21352735,  1.73601687, -1.19037495],
#        [ 0.1394976 ,  0.14071157, -0.82150798,  0.72247648],
#        [-0.35218953,  0.02263193, -0.12400121,  0.21613346],
#        [ 0.34064234, -0.09544771, -1.05401024,  0.10361279],
#        [ 0.78763064,  1.0853487 , -0.12400121,  0.94751783],
#        [-1.67080503, -1.39432376,  0.34100331, -1.41541629],
#        [ 1.43576368,  1.20342834,  0.10850105,  0.72247648],
#        [-0.75447901, -1.04008484,  1.03851009, -1.24663528],
#        [-1.49200971, -0.56776627,  1.50351461, -1.30289562],
# ...

# %%
y_train
# Out:
# array(['Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
# ...

# %%
x_test
# Out:
# array([[ 0.83232947, -0.09544771, -0.58900572,  0.72247648],
#        [-0.32984012,  0.14071157, -1.98401928,  0.10361279],
#        [-0.97797316, -0.44968663,  2.66602591, -1.35915595],
#        [ 0.67588356,  1.6757469 , -0.35650346,  1.39760052],
#        [-1.55905795, -1.04008484,  0.80600783, -1.30289562],
#        [ 0.51943766,  0.49495049,  0.57350557,  1.22881951],
#        [-0.82152725, -1.04008484,  1.03851009, -1.41541629],
#        [ 0.20654585,  0.96726906,  0.10850105,  0.49743514],
#        [-0.01694831,  1.0853487 , -0.58900572,  0.55369548],
#        [-0.12869538,  0.25879121, -0.58900572,  0.10361279],
#        [ 1.27931777,  0.25879121, -1.05401024,  1.00377816],
#        [-0.57568369,  0.61303014,  0.34100331,  0.38491447],
#        [-0.08399655,  0.25879121, -0.58900572,  0.49743514],
#        [-0.50863544,  0.73110978, -0.58900572,  0.4411748 ],
#        [-0.3074907 ,  0.25879121, -0.35650346,  0.49743514],
# ...

# %%
y_test
# Out:
# array(['Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa'], dtype=object)

# %% [markdown]
# #### Predicting the Test set results

# %%
y_pred = svc.predict(x_test)

# %%
y_pred
# Out:
# array(['Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa'], dtype=object)

# %%
y_test
# Out:
# array(['Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa'], dtype=object)

# %% [markdown]
# #### Model Evaluation

# %%
print("*"*120)
print("ACCURACY SCORE OF THE MODEL USING SVC ALGORITHM".center(100))
print("*"*120)
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
acc_svc = accuracy_score(y_test, y_pred)
print(acc_svc)
# Out:
# ************************************************************************************************************************
#                           ACCURACY SCORE OF THE MODEL USING SVC ALGORITHM
# ************************************************************************************************************************
# 1.0

# %%
print("*"*120)
print("PLOT FOR THE CONFUSION MATRIX OF THE MODEL USING SVC ALGORITHM".center(100))
print("*"*120)

from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(svc, x_test, y_test)
# Out:
# ************************************************************************************************************************
#                    PLOT FOR THE CONFUSION MATRIX OF THE MODEL USING SVC ALGORITHM
# ************************************************************************************************************************

# %%
print("Confusion Matrix:\n")
Matrix(confusion_matrix(y_test,y_pred))
# Out:
# Confusion Matrix:
# Matrix([
# [11,  0, 0],
# [ 0, 13, 0],
# [ 0,  0, 6]])

# %%
print("*"*120)
print("CLASSIFICATION REPORT OF THE MODEL USING SVC ALGORITHM".center(100))
print("*"*120)

class_report = classification_report(y_test, y_pred)

print(class_report)
# Out:
# ************************************************************************************************************************
#                        CLASSIFICATION REPORT OF THE MODEL USING SVC ALGORITHM
# ************************************************************************************************************************
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       1.00      1.00      1.00        13
#  Iris-virginica       1.00      1.00      1.00         6
#
#        accuracy                           1.00        30
#       macro avg       1.00      1.00      1.00        30
#    weighted avg       1.00      1.00      1.00        30

# %% [markdown]
# ## CONCLUSION :-
#
# - **The project taught me a lot about the scikit learn library, which is used for machine learning. This helped me exploring the datasets in kaggle and I learnt about splitting, training and testing the dataset and then normalizing the dataset using Minmax and standard scaler which enhanced my knowledge. Then I learnt about some of the algorithms which are decision tree, knn, logistic regression and random forest, svc with linear kernel, etc. This project helped me getting an overall idea of machine learning algorithms with few model evaluation techniques like accuracy score, confusion matrix and classification report.**

# %% [markdown]
# # THANK YOU
